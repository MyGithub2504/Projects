# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings('ignore')

# %%
Abalone_age=pd.read_csv("abalone_age.csv")
Abalone_age
# Out:
#      Sex  Length  Diameter  Height  Whole weight  Shucked weight  \
# 0      M   0.455     0.365   0.095        0.5140          0.2245
# 1      M   0.350     0.265   0.090        0.2255          0.0995
# 2      F   0.530     0.420   0.135        0.6770          0.2565
# 3      M   0.440     0.365   0.125        0.5160          0.2155
# 4      I   0.330     0.255   0.080        0.2050          0.0895
# ...   ..     ...       ...     ...           ...             ...
# 4172   F   0.565     0.450   0.165        0.8870          0.3700
# 4173   M   0.590     0.440   0.135        0.9660          0.4390
# 4174   M   0.600     0.475   0.205        1.1760          0.5255
# 4175   F   0.625     0.485   0.150        1.0945          0.5310
# 4176   M   0.710     0.555   0.195        1.9485          0.9455
#
#       Viscera weight  Shell weight  Rings
# 0             0.1010        0.1500     15
# 1             0.0485        0.0700      7
# 2             0.1415        0.2100      9
# ...

# %% [markdown]
# Here target variable is numeric so we will use regression analysis.

# %%
Abalone_age.shape
# Out:
# (4177, 9)

# %% [markdown]
# DataFrame is having 4177 rows and 9 columns

# %%
Abalone_age.dtypes
# Out:
# Sex                object
# Length            float64
# Diameter          float64
# Height            float64
# Whole weight      float64
# Shucked weight    float64
# Viscera weight    float64
# Shell weight      float64
# Rings               int64
# dtype: object

# %% [markdown]
# 'Sex' column is having object
#
# 'Rings' column is having int
#
# And others are having float datatype

# %%
Abalone_age.isnull().sum()
# Out:
# Sex               0
# Length            0
# Diameter          0
# Height            0
# Whole weight      0
# Shucked weight    0
# Viscera weight    0
# Shell weight      0
# Rings             0
# dtype: int64

# %%
Abalone_age.loc[Abalone_age["Rings"]== " "] #for checking empty value
# Out:
# Empty DataFrame
# Columns: [Sex, Length, Diameter, Height, Whole weight, Shucked weight, Viscera weight, Shell weight, Rings]
# Index: []

# %% [markdown]
# There is no missing value inside the dataset

# %% [markdown]
# # EDA ANALYSIS

# %%
from sklearn.preprocessing import LabelEncoder
LE=LabelEncoder()
Abalone_age["Sex"]=LE.fit_transform(Abalone_age['Sex'])

# %%
Abalone_age["Sex"].unique()
# Out:
# array([2, 0, 1])

# %%
Abalone_age
# Out:
#       Sex  Length  Diameter  Height  Whole weight  Shucked weight  \
# 0       2   0.455     0.365   0.095        0.5140          0.2245
# 1       2   0.350     0.265   0.090        0.2255          0.0995
# 2       0   0.530     0.420   0.135        0.6770          0.2565
# 3       2   0.440     0.365   0.125        0.5160          0.2155
# 4       1   0.330     0.255   0.080        0.2050          0.0895
# ...   ...     ...       ...     ...           ...             ...
# 4172    0   0.565     0.450   0.165        0.8870          0.3700
# 4173    2   0.590     0.440   0.135        0.9660          0.4390
# 4174    2   0.600     0.475   0.205        1.1760          0.5255
# 4175    0   0.625     0.485   0.150        1.0945          0.5310
# 4176    2   0.710     0.555   0.195        1.9485          0.9455
#
#       Viscera weight  Shell weight  Rings
# 0             0.1010        0.1500     15
# 1             0.0485        0.0700      7
# 2             0.1415        0.2100      9
# ...

# %% [markdown]
# Label Encoder is used since the value of one column is having string value
#
# to convert it into numeric value

# %% [markdown]
# ### Distribution plot

# %%
sns.distplot(Abalone_age["Length"])
# Out:
# <AxesSubplot:xlabel='Length', ylabel='Density'>

# %%
sns.distplot(Abalone_age["Diameter"])
# Out:
# <AxesSubplot:xlabel='Diameter', ylabel='Density'>

# %%
sns.distplot(Abalone_age["Height"])
# Out:
# <AxesSubplot:xlabel='Height', ylabel='Density'>

# %%
sns.distplot(Abalone_age["Whole weight"])
# Out:
# <AxesSubplot:xlabel='Whole weight', ylabel='Density'>

# %%
sns.distplot(Abalone_age["Shucked weight"])
# Out:
# <AxesSubplot:xlabel='Shucked weight', ylabel='Density'>

# %%
sns.distplot(Abalone_age["Viscera weight"])
# Out:
# <AxesSubplot:xlabel='Viscera weight', ylabel='Density'>

# %%
sns.distplot(Abalone_age["Shell weight"])
# Out:
# <AxesSubplot:xlabel='Shell weight', ylabel='Density'>

# %%
sns.distplot(Abalone_age["Rings"])
# Out:
# <AxesSubplot:xlabel='Rings', ylabel='Density'>

# %% [markdown]
# #### Box-plot for outlier detection

# %%
sns.boxplot(Abalone_age["Sex"])
# Out:
# <AxesSubplot:xlabel='Sex'>

# %%
sns.boxplot(Abalone_age["Length"])
# Out:
# <AxesSubplot:xlabel='Length'>

# %%
sns.boxplot(Abalone_age["Diameter"])
# Out:
# <AxesSubplot:xlabel='Diameter'>

# %%
sns.boxplot(Abalone_age["Height"])
# Out:
# <AxesSubplot:xlabel='Height'>

# %%
sns.boxplot(Abalone_age["Whole weight"])
# Out:
# <AxesSubplot:xlabel='Whole weight'>

# %%
sns.boxplot(Abalone_age["Shucked weight"])
# Out:
# <AxesSubplot:xlabel='Shucked weight'>

# %%
sns.boxplot(Abalone_age["Viscera weight"])
# Out:
# <AxesSubplot:xlabel='Viscera weight'>

# %%
sns.boxplot(Abalone_age["Shell weight"])
# Out:
# <AxesSubplot:xlabel='Shell weight'>

# %%
sns.boxplot(Abalone_age["Rings"])
# Out:
# <AxesSubplot:xlabel='Rings'>

# %% [markdown]
# From the boxplot analysis we can see that every column has outlier except 'sex' column

# %% [markdown]
# ## Bivariate Analysis

# %%
plt.figure(figsize=[10,6])
plt.title('Comparison between Length and Diameter')
sns.scatterplot(Abalone_age['Length'], Abalone_age['Diameter'], hue=Abalone_age["Rings"]);

# %%
plt.figure(figsize=[10,6])
plt.title('Comparison between Diameter and Height')
sns.scatterplot(Abalone_age['Diameter'], Abalone_age['Height'], hue=Abalone_age["Rings"]);

# %%
plt.figure(figsize=[10,6])
plt.title('Comparison between Height and Whole weight')
sns.scatterplot(Abalone_age['Height'], Abalone_age['Whole weight'], hue=Abalone_age["Rings"]);

# %%
plt.figure(figsize=[10,6])
plt.title('Comparison between Whole weight and Shucked weight')
sns.scatterplot(Abalone_age['Whole weight'], Abalone_age['Shucked weight'], hue=Abalone_age["Rings"]);

# %%
plt.figure(figsize=[10,6])
plt.title('Comparison between Shucked weight and Viscera weight')
sns.scatterplot(Abalone_age['Shucked weight'], Abalone_age['Viscera weight'], hue=Abalone_age["Rings"]);

# %%
plt.figure(figsize=[10,6])
plt.title('Comparison between Viscera weight and Shell weight')
sns.scatterplot(Abalone_age['Viscera weight'], Abalone_age['Shell weight'], hue=Abalone_age["Rings"]);

# %%
plt.figure(figsize=[10,6])
plt.title('Comparison between Shell weight and Rings')
sns.scatterplot(Abalone_age['Shell weight'], Abalone_age['Rings'], hue=Abalone_age["Rings"]);

# %% [markdown]
# High collinarity can be seen in Length and Diameter, Whole weoght and Shucked weight, Shucked weight and Viscera weight,
#
# Viscera weight and Shell weight

# %% [markdown]
# ## Multivariate Analysis

# %%
sns.pairplot(Abalone_age,hue="Rings")

# %%
Abalone_age.describe()
# Out:
#                Sex       Length     Diameter       Height  Whole weight  \
# count  4177.000000  4177.000000  4177.000000  4177.000000   4177.000000
# mean      1.052909     0.523992     0.407881     0.139516      0.828742
# std       0.822240     0.120093     0.099240     0.041827      0.490389
# min       0.000000     0.075000     0.055000     0.000000      0.002000
# 25%       0.000000     0.450000     0.350000     0.115000      0.441500
# 50%       1.000000     0.545000     0.425000     0.140000      0.799500
# 75%       2.000000     0.615000     0.480000     0.165000      1.153000
# max       2.000000     0.815000     0.650000     1.130000      2.825500
#
#        Shucked weight  Viscera weight  Shell weight        Rings
# count     4177.000000     4177.000000   4177.000000  4177.000000
# mean         0.359367        0.180594      0.238831     9.933684
# std          0.221963        0.109614      0.139203     3.224169
# ...

# %%
cor=Abalone_age.corr()
cor
# Out:
#                      Sex    Length  Diameter    Height  Whole weight  \
# Sex             1.000000 -0.036066 -0.038874 -0.042077     -0.021391
# Length         -0.036066  1.000000  0.986812  0.827554      0.925261
# Diameter       -0.038874  0.986812  1.000000  0.833684      0.925452
# Height         -0.042077  0.827554  0.833684  1.000000      0.819221
# Whole weight   -0.021391  0.925261  0.925452  0.819221      1.000000
# Shucked weight -0.001373  0.897914  0.893162  0.774972      0.969405
# Viscera weight -0.032067  0.903018  0.899724  0.798319      0.966375
# Shell weight   -0.034854  0.897706  0.905330  0.817338      0.955355
# Rings          -0.034627  0.556720  0.574660  0.557467      0.540390
#
#                 Shucked weight  Viscera weight  Shell weight     Rings
# Sex                  -0.001373       -0.032067     -0.034854 -0.034627
# Length                0.897914        0.903018      0.897706  0.556720
# ...

# %%
plt.figure(figsize=(10,6))
sns.heatmap(cor,cmap='Greens',annot=True)
# Out:
# <AxesSubplot:>

# %% [markdown]
# Observations:
#
# High correlation between Length and Shell weight that is 0.9
#
# High correlation between Length and Viscera weight that is 0.9
#
# High correlation between Length and Shucked weight that is 0.9
#
# High correlation between Length and Whole weight that is 0.93
#
# High correlation between Length and Height that is 0.83
#
# High correlation between Length and Diameter that is 0.99
#
# High correlation between Diameter and Shell weight that is 0.91
#
# High correlation between Diameter and Viscera weight that is 0.9
#
# High correlation between Diameter and Shucked weight that is 0.89
#
# High correlation between Diameter and Whole weight that is 0.93
#
# High correlation between Diameter and Height that is 0.83
#
# High correlation between Height and Shell weight that is 0.82
#
# High correlation between Height and Viscera weight that is 0.8
#
# High correlation between Height and Shucked weight that is 0.77
#
# High correlation between Height and Whole weight that is 0.82
#
# High correlation between Whole weight and Shell weight that is 0.96
#
# High correlation between Whole weight and Viscera weight that is 0.97
#
# High correlation between Whole weight and Shucked weight that is 0.97
#
# High correlation between Shucked weight and Shell weight that is 0.88
#
# High correlation between Shucked weight and Viscera weight that is 0.93
#
# High correlation between Viscera weight and Shell weight that is 0.91

# %% [markdown]
# ### Z-Score for outlier removal

# %%
from scipy.stats import zscore
z=np.abs(zscore(Abalone_age))
Abalone_new=Abalone_age[(z<3).all(axis=1)]

# %%
Abalone_new.shape
# Out:
# (4027, 9)

# %%
Abalone_age.shape
# Out:
# (4177, 9)

# %%
150/4177
# Out:
# 0.035910940866650705

# %% [markdown]
# So the outliers have been removed since percent loss in data is less than 5 percent

# %% [markdown]
# ## Skewness

# %%
Abalone_new
# Out:
#       Sex  Length  Diameter  Height  Whole weight  Shucked weight  \
# 0       2   0.455     0.365   0.095        0.5140          0.2245
# 1       2   0.350     0.265   0.090        0.2255          0.0995
# 2       0   0.530     0.420   0.135        0.6770          0.2565
# 3       2   0.440     0.365   0.125        0.5160          0.2155
# 4       1   0.330     0.255   0.080        0.2050          0.0895
# ...   ...     ...       ...     ...           ...             ...
# 4172    0   0.565     0.450   0.165        0.8870          0.3700
# 4173    2   0.590     0.440   0.135        0.9660          0.4390
# 4174    2   0.600     0.475   0.205        1.1760          0.5255
# 4175    0   0.625     0.485   0.150        1.0945          0.5310
# 4176    2   0.710     0.555   0.195        1.9485          0.9455
#
#       Viscera weight  Shell weight  Rings
# 0             0.1010        0.1500     15
# 1             0.0485        0.0700      7
# 2             0.1415        0.2100      9
# ...

# %%
Abalone_new.skew()
# Out:
# Sex              -0.094886
# Length           -0.623076
# Diameter         -0.598650
# Height           -0.244251
# Whole weight      0.334204
# Shucked weight    0.458295
# Viscera weight    0.437116
# Shell weight      0.349471
# Rings             0.725464
# dtype: float64

# %% [markdown]
# Skewness can be seen in various columns
# Positive skewness :
# Rings
#
# Negative skewness :
# Length, Diameter,

# %%
x=Abalone_new.iloc[:,:-1]
x
# Out:
#       Sex  Length  Diameter  Height  Whole weight  Shucked weight  \
# 0       2   0.455     0.365   0.095        0.5140          0.2245
# 1       2   0.350     0.265   0.090        0.2255          0.0995
# 2       0   0.530     0.420   0.135        0.6770          0.2565
# 3       2   0.440     0.365   0.125        0.5160          0.2155
# 4       1   0.330     0.255   0.080        0.2050          0.0895
# ...   ...     ...       ...     ...           ...             ...
# 4172    0   0.565     0.450   0.165        0.8870          0.3700
# 4173    2   0.590     0.440   0.135        0.9660          0.4390
# 4174    2   0.600     0.475   0.205        1.1760          0.5255
# 4175    0   0.625     0.485   0.150        1.0945          0.5310
# 4176    2   0.710     0.555   0.195        1.9485          0.9455
#
#       Viscera weight  Shell weight
# 0             0.1010        0.1500
# 1             0.0485        0.0700
# 2             0.1415        0.2100
# ...

# %%
y=Abalone_new.iloc[:,-1]
y
# Out:
# 0       15
# 1        7
# 2        9
# 3       10
# 4        7
#         ..
# 4172    11
# 4173    10
# 4174     9
# 4175    10
# 4176    12
# Name: Rings, Length: 4027, dtype: int64

# %% [markdown]
# ### Skewness removal using Power_Transform method

# %% [markdown]
# from sklearn.preprocessing import power_transform
# X=power_transform(x, method='yeo-johnson')
# X

# %% [markdown]
# from sklearn.preprocessing import StandardScaler
# SC=StandardScaler()
# Rings_X=SC.fit_transform(X)
# Rings_X

# %% [markdown]
# Rings_Y=y

# %% [markdown]
# ## train_test_split

# %%
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_squared_error,r2_score, mean_absolute_error
from sklearn.model_selection import train_test_split
from sklearn.metrics import r2_score

# %%
for i in range(200):
    x_train, x_test, y_train, y_test=train_test_split(x,y,test_size=0.30, random_state=i)
    from sklearn.tree import DecisionTreeRegressor
    DTR=DecisionTreeRegressor()
    DTR.fit(x_train,y_train)
    pred=DTR.predict(x_test)
    
    print("r2score at random state",i,"is",r2_score(y_test,pred))
    print('error:')
    print('Mean absolute error :', mean_absolute_error(y_test,pred))
    print('Mean squared error :', mean_squared_error(y_test,pred))
    print('Root mean Squared Error :', np.sqrt(mean_squared_error(y_test,pred)))
# Out:
# r2score at random state 0 is 0.0912372967970515
# error:
# Mean absolute error : 1.9280397022332507
# Mean squared error : 7.272952853598015
# Root mean Squared Error : 2.696841273341465
# r2score at random state 1 is -0.045875249351150726
# error:
# Mean absolute error : 2.0281224152191895
# Mean squared error : 8.272952853598015
# Root mean Squared Error : 2.8762741269910306
# r2score at random state 2 is 0.23868931133345628
# error:
# Mean absolute error : 1.8188585607940446
# Mean squared error : 6.4557485525227465
# Root mean Squared Error : 2.5408165129585307
# r2score at random state 3 is 0.028419648313168788
# error:
# Mean absolute error : 1.9611248966087675
# Mean squared error : 7.694789081885856
# Root mean Squared Error : 2.7739482839241716
# r2score at random state 4 is 0.05605577410478302
# error:
# Mean absolute error : 1.8858560794044665
# Mean squared error : 7.217535153019024
# Root mean Squared Error : 2.68654706882627
# ...

# %%
from sklearn.tree import DecisionTreeRegressor
maxr2=0
maxRS=0
for i in range(1,200):
    x_train, x_test, y_train, y_test=train_test_split(x,y,test_size=0.33, random_state=i)
    mod=DecisionTreeRegressor()
    mod.fit(x_train,y_train)
    pred=mod.predict(x_test)
    r2=r2_score(y_test,pred)
    if r2>maxr2:
        maxr2=r2
        maxRS=i
print("Best accuracy is ", maxr2, "on Random_state", maxRS)
# Out:
# Best accuracy is  0.24175491585510467 on Random_state 96

# %%
x_train, x_test, y_train, y_test=train_test_split(x,y,test_size=0.33, random_state=96)

# %% [markdown]
# Now checking for r2_score using 5 algorithms

# %%
from sklearn.svm import SVR

SV=SVR(kernel="linear")
SV.fit(x_train,y_train)
SV.score(x_train,y_train)
pred_y=SV.predict(x_test)
print(SV.score(x_train,y_train))
# Out:
# 0.4450921990471126

# %%
import numpy as np
from sklearn.linear_model import LinearRegression
REG = LinearRegression()
REG.fit(x_train, y_train)
REG.score(x_train, y_train)
# Out:
# 0.5033300481038554

# %%
REG.coef_
# Out:
# array([  0.07635043,  -4.5293107 ,  15.14926535,  20.30036907,
#          8.13797915, -18.4724405 ,  -6.6750737 ,   5.66126112])

# %%
REG.intercept_
# Out:
# 2.850105595183736

# %%
from sklearn.tree import DecisionTreeRegressor
DTR=DecisionTreeRegressor()
DTR.fit(x_train,y_train)
pred=DTR.predict(x_test)
    
print(r2_score(y_test,pred))
# Out:
# 0.16566927185268454

# %%
from sklearn.ensemble import RandomForestRegressor
RFReg = RandomForestRegressor(max_depth=2, random_state=0)
RFReg.fit(x_train, y_train)
pred=(RFReg.predict(x_test))
print(RFReg.score(x_test,pred))
# Out:
# 1.0

# %%
# ElasticNet is a combination of both Lasso and Ridge

from sklearn.linear_model import ElasticNet
ENR=ElasticNet(alpha=0.01)
#enr=ElasticNet()
ENR.fit(x_train,y_train)
Enrpred=ENR.predict(x_test)
print(ENR.score(x_train,y_train))
ENR.coef_
# Out:
# 0.40027752882238044
# array([ 0.        ,  1.97649756,  2.38164436,  1.06738715,  3.16399763,
#        -4.64802211,  0.        ,  4.3932826 ])

# %% [markdown]
# Now we will check the cross validation score

# %%
from sklearn.model_selection import cross_val_score

# %%
print(cross_val_score(SV,x,y,cv=5).mean())
# Out:
# 0.39895154578038566

# %%
print(cross_val_score(REG,x,y,cv=5).mean())
# Out:
# 0.4148020401486133

# %%
print(cross_val_score(DTR,x,y,cv=5).mean())
# Out:
# -0.08361051556926327

# %%
print(cross_val_score(RFReg,x,y,cv=5).mean())
# Out:
# 0.274775238238883

# %%
print(cross_val_score(ENR,x,y,cv=5).mean())
# Out:
# 0.2903857500349452

# %% [markdown]
# The model showing least difference between two models SV.
#
#
# We have chosen SV as our best model.

# %% [markdown]
# # Hyper parameter tuning

# %%
from sklearn.model_selection import GridSearchCV

# %%
parameter = {
'max_iter':np.arange(1,8),
'coef0':np.arange(1,8),
'tol':np.arange(1,7),
'epsilon':np.arange(1,6)}

# %%
GCV=GridSearchCV(SVR(),parameter,cv=5)

# %%
GCV.fit(x_train,y_train)
# Out:
# GridSearchCV(cv=5, estimator=SVR(),
#              param_grid={'coef0': array([1, 2, 3, 4, 5, 6, 7]),
#                          'epsilon': array([1, 2, 3, 4, 5]),
#                          'max_iter': array([1, 2, 3, 4, 5, 6, 7]),
#                          'tol': array([1, 2, 3, 4, 5, 6])})

# %%
GCV.best_params_
# Out:
# {'coef0': 1, 'epsilon': 5, 'max_iter': 6, 'tol': 1}

# %%
Final_model= DecisionTreeRegressor(coef0 = 1, epsilon =5, max_iter=6, tol=1)
Final_model.fit(x_train, y_train)
pred = Final_model.predict(x_test)
r2score=r2_score(y_test,pred)
print(r2score*100)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-95-ce913b0f7d8a> in <module>
# ----> 1 Final_model= DecisionTreeRegressor(coef0 = 1, epsilon =5, max_iter=6, tol=1)
#       2 Final_model.fit(x_train, y_train)
#       3 pred = Final_model.predict(x_test)
#       4 r2score=r2_score(y_test,pred)
#       5 print(r2score*100)
#
# TypeError: __init__() got an unexpected keyword argument 'coef0'
