# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings('ignore')

# %%
Mushroom=pd.read_csv("Mushroom_data.csv")
Mushroom
# Out:
#      class cap-shape cap-surface cap-color bruises odor gill-attachment  \
# 0        p         x           s         n       t    p               f
# 1        e         x           s         y       t    a               f
# 2        e         b           s         w       t    l               f
# 3        p         x           y         w       t    p               f
# 4        e         x           s         g       f    n               f
# ...    ...       ...         ...       ...     ...  ...             ...
# 8119     e         k           s         n       f    n               a
# 8120     e         x           s         n       f    n               a
# 8121     e         f           s         n       f    n               a
# 8122     p         k           y         n       f    y               f
# 8123     e         x           s         n       f    n               a
#
#      gill-spacing gill-size gill-color  ... stalk-surface-below-ring  \
# ...

# %% [markdown]
# Here the target variable is string so we will use the classification method

# %%
Mushroom_data=Mushroom.reindex(columns= ['cap-shape', 'cap-surface', 'cap-color','bruises','odor','gill-attachment','gill-spacing','gill-size','gill-color','stalk-shape',
'stalk-root','stalk-surface-above-ring','stalk-surface-below-ring','stalk-color-above-ring','stalk-color-below-ring','veil-type','veil-color','ring-number','ring-type','spore-print-color','population','habitat','class'])
Mushroom_data
# Out:
#      cap-shape cap-surface cap-color bruises odor gill-attachment  \
# 0            x           s         n       t    p               f
# 1            x           s         y       t    a               f
# 2            b           s         w       t    l               f
# 3            x           y         w       t    p               f
# 4            x           s         g       f    n               f
# ...        ...         ...       ...     ...  ...             ...
# 8119         k           s         n       f    n               a
# 8120         x           s         n       f    n               a
# 8121         f           s         n       f    n               a
# 8122         k           y         n       f    y               f
# 8123         x           s         n       f    n               a
#
#      gill-spacing gill-size gill-color stalk-shape  ...  \
# 0               c         n          k           e  ...
# 1               c         b          k           e  ...
# ...

# %%
Mushroom_data.shape
# Out:
# (8124, 23)

# %%
Mushroom_data.head(10)
# Out:
#   cap-shape cap-surface cap-color bruises odor gill-attachment gill-spacing  \
# 0         x           s         n       t    p               f            c
# 1         x           s         y       t    a               f            c
# 2         b           s         w       t    l               f            c
# 3         x           y         w       t    p               f            c
# 4         x           s         g       f    n               f            w
# 5         x           y         y       t    a               f            c
# 6         b           s         w       t    a               f            c
# 7         b           y         w       t    l               f            c
# 8         x           y         w       t    p               f            c
# 9         b           s         y       t    a               f            c
#
#   gill-size gill-color stalk-shape  ... stalk-color-above-ring  \
# 0         n          k           e  ...                      w
# ...

# %% [markdown]
# We have 8124 rows and 23 columns in our dataframe

# %%
Mushroom_data.tail(10)
# Out:
#      cap-shape cap-surface cap-color bruises odor gill-attachment  \
# 8114         f           y         c       f    m               a
# 8115         x           s         n       f    n               a
# 8116         k           y         n       f    s               f
# 8117         k           s         e       f    y               f
# 8118         k           y         n       f    f               f
# 8119         k           s         n       f    n               a
# 8120         x           s         n       f    n               a
# 8121         f           s         n       f    n               a
# 8122         k           y         n       f    y               f
# 8123         x           s         n       f    n               a
#
#      gill-spacing gill-size gill-color stalk-shape  ...  \
# 8114            c         b          y           e  ...
# 8115            c         b          y           e  ...
# 8116            c         n          b           t  ...
# ...

# %%
Mushroom_data.dtypes
# Out:
# cap-shape                   object
# cap-surface                 object
# cap-color                   object
# bruises                     object
# odor                        object
# gill-attachment             object
# gill-spacing                object
# gill-size                   object
# gill-color                  object
# stalk-shape                 object
# stalk-root                  object
# stalk-surface-above-ring    object
# stalk-surface-below-ring    object
# stalk-color-above-ring      object
# stalk-color-below-ring      object
# veil-type                   object
# veil-color                  object
# ring-number                 object
# ring-type                   object
# spore-print-color           object
# population                  object
# habitat                     object
# class                       object
# dtype: object

# %% [markdown]
# Here in this we have object datatypes in all the columns

# %%
Mushroom_data.isnull().sum()
# Out:
# cap-shape                   0
# cap-surface                 0
# cap-color                   0
# bruises                     0
# odor                        0
# gill-attachment             0
# gill-spacing                0
# gill-size                   0
# gill-color                  0
# stalk-shape                 0
# stalk-root                  0
# stalk-surface-above-ring    0
# stalk-surface-below-ring    0
# stalk-color-above-ring      0
# stalk-color-below-ring      0
# veil-type                   0
# veil-color                  0
# ring-number                 0
# ring-type                   0
# spore-print-color           0
# population                  0
# habitat                     0
# class                       0
# dtype: int64

# %% [markdown]
# We don't have any missing value in our dataset

# %% [markdown]
# # EDA ANALYSIS

# %%
Mushroom_data['class'].unique()
# Out:
# array(['p', 'e'], dtype=object)

# %%
Mushroom_data['class'].value_counts()
# Out:
# e    4208
# p    3916
# Name: class, dtype: int64

# %% [markdown]
# Since both the classes nearly have equal number of unique values there is no requirement to do balancing.

# %% [markdown]
# Here we have find that class column have 2 unique values

# %%
from sklearn.preprocessing import LabelEncoder
LE=LabelEncoder()
Mushroom_data["cap-shape"]=LE.fit_transform(Mushroom_data["cap-shape"])
Mushroom_data["cap-surface"]=LE.fit_transform(Mushroom_data["cap-surface"])
Mushroom_data["cap-color"]=LE.fit_transform(Mushroom_data["cap-color"])
Mushroom_data["bruises"]=LE.fit_transform(Mushroom_data["bruises"])
Mushroom_data["odor"]=LE.fit_transform(Mushroom_data["odor"])
Mushroom_data["gill-attachment"]=LE.fit_transform(Mushroom_data["gill-attachment"])
Mushroom_data["gill-spacing"]=LE.fit_transform(Mushroom_data["gill-spacing"])
Mushroom_data["gill-size"]=LE.fit_transform(Mushroom_data["gill-size"])
Mushroom_data["gill-color"]=LE.fit_transform(Mushroom_data["gill-color"])
Mushroom_data["stalk-shape"]=LE.fit_transform(Mushroom_data["stalk-shape"])
Mushroom_data["stalk-root"]=LE.fit_transform(Mushroom_data["stalk-root"])
Mushroom_data["stalk-surface-above-ring"]=LE.fit_transform(Mushroom_data["stalk-surface-above-ring"])
Mushroom_data["stalk-surface-below-ring"]=LE.fit_transform(Mushroom_data["stalk-surface-below-ring"])
Mushroom_data["stalk-color-above-ring"]=LE.fit_transform(Mushroom_data["stalk-color-above-ring"])
Mushroom_data["stalk-color-below-ring"]=LE.fit_transform(Mushroom_data["stalk-color-below-ring"])
Mushroom_data["veil-type"]=LE.fit_transform(Mushroom_data["veil-type"])
Mushroom_data["veil-color"]=LE.fit_transform(Mushroom_data["veil-color"])
Mushroom_data["ring-number"]=LE.fit_transform(Mushroom_data["ring-number"])
Mushroom_data["ring-type"]=LE.fit_transform(Mushroom_data["ring-type"])
Mushroom_data["spore-print-color"]=LE.fit_transform(Mushroom_data["spore-print-color"])
Mushroom_data["population"]=LE.fit_transform(Mushroom_data["population"])
Mushroom_data["habitat"]=LE.fit_transform(Mushroom_data["habitat"])
Mushroom_data["class"]=LE.fit_transform(Mushroom_data["class"])

# %%
Mushroom_data["cap-shape"].unique()
# Out:
# array([5, 0, 4, 2, 3, 1])

# %%
Mushroom_data["cap-surface"].unique()
# Out:
# array([2, 3, 0, 1])

# %%
Mushroom_data["cap-color"].unique()
# Out:
# array([4, 9, 8, 3, 2, 5, 0, 7, 1, 6])

# %%
Mushroom_data["bruises"].unique()
# Out:
# array([1, 0])

# %%
Mushroom_data["odor"].unique()
# Out:
# array([6, 0, 3, 5, 2, 1, 8, 7, 4])

# %%
Mushroom_data["gill-attachment"].unique()
# Out:
# array([1, 0])

# %%
Mushroom_data["gill-spacing"].unique()
# Out:
# array([0, 1])

# %%
Mushroom_data["gill-size"].unique()
# Out:
# array([1, 0])

# %%
Mushroom_data["gill-color"].unique()
# Out:
# array([ 4,  5,  2,  7, 10,  3,  9,  1,  0,  8, 11,  6])

# %%
Mushroom_data["stalk-shape"].unique()
# Out:
# array([0, 1])

# %%
Mushroom_data["stalk-root"].unique()
# Out:
# array([3, 2, 1, 4, 0])

# %%
Mushroom_data["stalk-surface-above-ring"].unique()
# Out:
# array([2, 0, 1, 3])

# %%
Mushroom_data["stalk-surface-below-ring"].unique()
# Out:
# array([2, 0, 3, 1])

# %%
Mushroom_data["stalk-color-above-ring"].unique()
# Out:
# array([7, 3, 6, 4, 0, 2, 5, 1, 8])

# %%
Mushroom_data["stalk-color-below-ring"].unique()
# Out:
# array([7, 6, 3, 0, 4, 2, 8, 5, 1])

# %%
Mushroom_data["veil-type"].unique()
# Out:
# array([0])

# %%
Mushroom_data["veil-color"].unique()
# Out:
# array([2, 0, 1, 3])

# %%
Mushroom_data["ring-number"].unique()
# Out:
# array([1, 2, 0])

# %%
Mushroom_data["ring-type"].unique()
# Out:
# array([4, 0, 2, 1, 3])

# %%
Mushroom_data["spore-print-color"].unique()
# Out:
# array([2, 3, 6, 1, 7, 5, 4, 8, 0])

# %%
Mushroom_data["population"].unique()
# Out:
# array([3, 2, 0, 4, 5, 1])

# %%
Mushroom_data["habitat"].unique()
# Out:
# array([5, 1, 3, 0, 4, 6, 2])

# %%
Mushroom_data["class"].unique()
# Out:
# array([1, 0])

# %%
Mushroom_data
# Out:
#       cap-shape  cap-surface  cap-color  bruises  odor  gill-attachment  \
# 0             5            2          4        1     6                1
# 1             5            2          9        1     0                1
# 2             0            2          8        1     3                1
# 3             5            3          8        1     6                1
# 4             5            2          3        0     5                1
# ...         ...          ...        ...      ...   ...              ...
# 8119          3            2          4        0     5                0
# 8120          5            2          4        0     5                0
# 8121          2            2          4        0     5                0
# 8122          3            3          4        0     8                1
# 8123          5            2          4        0     5                0
#
#       gill-spacing  gill-size  gill-color  stalk-shape  ...  \
# ...

# %%
sns.countplot(Mushroom_data["class"]);

# %%
sns.distplot(Mushroom_data["cap-shape"])
# Out:
# <AxesSubplot:xlabel='cap-shape', ylabel='Density'>

# %%
sns.distplot(Mushroom_data["cap-surface"])
# Out:
# <AxesSubplot:xlabel='cap-surface', ylabel='Density'>

# %%
sns.distplot(Mushroom_data["cap-color"])
# Out:
# <AxesSubplot:xlabel='cap-color', ylabel='Density'>

# %%
sns.distplot(Mushroom_data["bruises"])
# Out:
# <AxesSubplot:xlabel='bruises', ylabel='Density'>

# %%
sns.distplot(Mushroom_data["odor"])
# Out:
# <AxesSubplot:xlabel='odor', ylabel='Density'>

# %%
sns.distplot(Mushroom_data["gill-attachment"])
# Out:
# <AxesSubplot:xlabel='gill-attachment', ylabel='Density'>

# %%
sns.distplot(Mushroom_data["gill-spacing"])
# Out:
# <AxesSubplot:xlabel='gill-spacing', ylabel='Density'>

# %%
sns.distplot(Mushroom_data["gill-size"])
# Out:
# <AxesSubplot:xlabel='gill-size', ylabel='Density'>

# %%
sns.distplot(Mushroom_data["gill-color"])
# Out:
# <AxesSubplot:xlabel='gill-color', ylabel='Density'>

# %%
sns.distplot(Mushroom_data["stalk-shape"])
# Out:
# <AxesSubplot:xlabel='stalk-shape', ylabel='Density'>

# %%
sns.distplot(Mushroom_data["stalk-root"])
# Out:
# <AxesSubplot:xlabel='stalk-root', ylabel='Density'>

# %%
sns.distplot(Mushroom_data["stalk-surface-above-ring"])
# Out:
# <AxesSubplot:xlabel='stalk-surface-above-ring', ylabel='Density'>

# %%
sns.distplot(Mushroom_data["stalk-surface-below-ring"])
# Out:
# <AxesSubplot:xlabel='stalk-surface-below-ring', ylabel='Density'>

# %%
sns.distplot(Mushroom_data["stalk-color-above-ring"])
# Out:
# <AxesSubplot:xlabel='stalk-color-above-ring', ylabel='Density'>

# %%
sns.distplot(Mushroom_data["stalk-color-below-ring"])
# Out:
# <AxesSubplot:xlabel='stalk-color-below-ring', ylabel='Density'>

# %%
sns.distplot(Mushroom_data["veil-type"])
# Out:
# <AxesSubplot:xlabel='veil-type', ylabel='Density'>

# %%
sns.distplot(Mushroom_data["veil-color"])
# Out:
# <AxesSubplot:xlabel='veil-color', ylabel='Density'>

# %%
sns.distplot(Mushroom_data["ring-number"])
# Out:
# <AxesSubplot:xlabel='ring-number', ylabel='Density'>

# %%
sns.distplot(Mushroom_data["ring-type"])
# Out:
# <AxesSubplot:xlabel='ring-type', ylabel='Density'>

# %%
sns.distplot(Mushroom_data["spore-print-color"])
# Out:
# <AxesSubplot:xlabel='spore-print-color', ylabel='Density'>

# %%
sns.distplot(Mushroom_data["population"])
# Out:
# <AxesSubplot:xlabel='population', ylabel='Density'>

# %%
sns.distplot(Mushroom_data["habitat"])
# Out:
# <AxesSubplot:xlabel='habitat', ylabel='Density'>

# %%
sns.distplot(Mushroom_data["class"])
# Out:
# <AxesSubplot:xlabel='class', ylabel='Density'>

# %%
sns.boxplot(Mushroom_data["cap-shape"])
# Out:
# <AxesSubplot:xlabel='cap-shape'>

# %%
sns.boxplot(Mushroom_data["cap-surface"])
# Out:
# <AxesSubplot:xlabel='cap-surface'>

# %%
sns.boxplot(Mushroom_data["cap-color"])
# Out:
# <AxesSubplot:xlabel='cap-color'>

# %%
sns.boxplot(Mushroom_data["bruises"])
# Out:
# <AxesSubplot:xlabel='bruises'>

# %%
sns.boxplot(Mushroom_data["odor"])
# Out:
# <AxesSubplot:xlabel='odor'>

# %%
sns.boxplot(Mushroom_data["gill-attachment"])
# Out:
# <AxesSubplot:xlabel='gill-attachment'>

# %%
sns.boxplot(Mushroom_data["gill-spacing"])
# Out:
# <AxesSubplot:xlabel='gill-spacing'>

# %%
sns.boxplot(Mushroom_data["gill-size"])
# Out:
# <AxesSubplot:xlabel='gill-size'>

# %%
sns.boxplot(Mushroom_data["gill-color"])
# Out:
# <AxesSubplot:xlabel='gill-color'>

# %%
sns.boxplot(Mushroom_data["stalk-shape"])
# Out:
# <AxesSubplot:xlabel='stalk-shape'>

# %%
sns.boxplot(Mushroom_data["stalk-root"])
# Out:
# <AxesSubplot:xlabel='stalk-root'>

# %%
sns.boxplot(Mushroom_data["stalk-surface-above-ring"])
# Out:
# <AxesSubplot:xlabel='stalk-surface-above-ring'>

# %%
sns.boxplot(Mushroom_data["stalk-surface-below-ring"])
# Out:
# <AxesSubplot:xlabel='stalk-surface-below-ring'>

# %%
sns.boxplot(Mushroom_data["stalk-color-above-ring"])
# Out:
# <AxesSubplot:xlabel='stalk-color-above-ring'>

# %%
sns.boxplot(Mushroom_data["stalk-color-below-ring"])
# Out:
# <AxesSubplot:xlabel='stalk-color-below-ring'>

# %%
sns.boxplot(Mushroom_data["veil-type"])
# Out:
# <AxesSubplot:xlabel='veil-type'>

# %%
sns.boxplot(Mushroom_data["veil-color"])
# Out:
# <AxesSubplot:xlabel='veil-color'>

# %%
sns.boxplot(Mushroom_data["ring-number"])
# Out:
# <AxesSubplot:xlabel='ring-number'>

# %%
sns.boxplot(Mushroom_data["ring-type"])
# Out:
# <AxesSubplot:xlabel='ring-type'>

# %%
sns.(Mushroom_data["spore-print-color"]).boxplot
# Out:
# <AxesSubplot:xlabel='spore-print-color'>

# %%
sns.boxplot(Mushroom_data["population"])
# Out:
# <AxesSubplot:xlabel='population'>

# %%
sns.boxplot(Mushroom_data["habitat"])
# Out:
# <AxesSubplot:xlabel='habitat'>

# %%
sns.boxplot(Mushroom_data["class"])
# Out:
# <AxesSubplot:xlabel='class'>

# %% [markdown]
# There are outliers in some of the columns:
#
# gill-attachment, gill-spacing, stalk-root, stalk-color-above-ring,
#
# stalk-color-below-ring, veil-color, ring-number, population, habitat

# %% [markdown]
# # BIVARIATE ANALYSIS

# %%
plt.figure(figsize=[10,6])
plt.title('Comparison between cap-shape and cap-surface')
sns.scatterplot(Mushroom_data['cap-shape'], Mushroom_data['cap-surface'], hue=Mushroom_data["class"]);

# %%
plt.figure(figsize=[10,6])
plt.title('Comparison between cap-surface and cap-color')
sns.scatterplot(Mushroom_data['cap-surface'], Mushroom_data['cap-color'], hue=Mushroom_data["class"]);

# %%
plt.figure(figsize=[10,6])
plt.title('Comparison between cap-surface and cap-color')
sns.scatterplot(Mushroom_data['cap-surface'], Mushroom_data['cap-color'], hue=Mushroom_data["class"]);

# %%
plt.figure(figsize=[10,6])
plt.title('Comparison between cap-color and bruises')
sns.scatterplot(Mushroom_data['cap-color'], Mushroom_data['bruises'], hue=Mushroom_data["class"]);

# %%
plt.figure(figsize=[10,6])
plt.title('Comparison between bruises and odor')
sns.scatterplot(Mushroom_data['bruises'], Mushroom_data['odor'], hue=Mushroom_data["class"]);

# %%
plt.figure(figsize=[10,6])
plt.title('Comparison between odor and gill-attachment')
sns.scatterplot(Mushroom_data['odor'], Mushroom_data['gill-attachment'], hue=Mushroom_data["class"]);

# %%
plt.figure(figsize=[10,6])
plt.title('Comparison between gill-attachment and gill-spacing')
sns.scatterplot(Mushroom_data['gill-attachment'], Mushroom_data['gill-spacing'], hue=Mushroom_data["class"]);

# %%
plt.figure(figsize=[10,6])
plt.title('Comparison between gill-spacing and gill-size')
sns.scatterplot(Mushroom_data['gill-spacing'], Mushroom_data['gill-size'], hue=Mushroom_data["class"]);

# %%
plt.figure(figsize=[10,6])
plt.title('Comparison between gill-size and gill-color')
sns.scatterplot(Mushroom_data['gill-size'], Mushroom_data['gill-color'], hue=Mushroom_data["class"]);

# %%
plt.figure(figsize=[10,6])
plt.title('Comparison between gill-color and stalk-shape')
sns.scatterplot(Mushroom_data['gill-color'], Mushroom_data['stalk-shape'], hue=Mushroom_data["class"]);

# %%
plt.figure(figsize=[10,6])
plt.title('Comparison between stalk-shape and stalk-root')
sns.scatterplot(Mushroom_data['stalk-shape'], Mushroom_data['stalk-root'], hue=Mushroom_data["class"]);

# %%
plt.figure(figsize=[10,6])
plt.title('Comparison between stalk-root and stalk-surface-above-ring')
sns.scatterplot(Mushroom_data['stalk-root'], Mushroom_data['stalk-surface-above-ring'], hue=Mushroom_data["class"]);

# %%
plt.figure(figsize=[10,6])
plt.title('Comparison between stalk-surface-above-ring and stalk-surface-below-ring')
sns.scatterplot(Mushroom_data['stalk-surface-above-ring'], Mushroom_data['stalk-surface-below-ring'], hue=Mushroom_data["class"]);

# %%
plt.figure(figsize=[10,6])
plt.title('Comparison between stalk-surface-below-ring and stalk-color-above-ring')
sns.scatterplot(Mushroom_data['stalk-surface-below-ring'], Mushroom_data['stalk-color-above-ring'], hue=Mushroom_data["class"]);

# %%
plt.figure(figsize=[10,6])
plt.title('Comparison between stalk-color-above-ring and stalk-color-below-ring')
sns.scatterplot(Mushroom_data['stalk-color-above-ring'], Mushroom_data['stalk-color-below-ring'], hue=Mushroom_data["class"]);

# %%
plt.figure(figsize=[10,6])
plt.title('Comparison between stalk-color-below-ring and veil-type')
sns.scatterplot(Mushroom_data['stalk-color-below-ring'], Mushroom_data['veil-type'], hue=Mushroom_data["class"]);

# %%
plt.figure(figsize=[10,6])
plt.title('Comparison between veil-type and veil-color')
sns.scatterplot(Mushroom_data['veil-type'], Mushroom_data['veil-color'], hue=Mushroom_data["class"]);

# %%
plt.figure(figsize=[10,6])
plt.title('Comparison between veil-color and ring-number')
sns.scatterplot(Mushroom_data['veil-color'], Mushroom_data['ring-number'], hue=Mushroom_data["class"]);

# %%
plt.figure(figsize=[10,6])
plt.title('Comparison between ring-number and ring-type')
sns.scatterplot(Mushroom_data['ring-number'], Mushroom_data['ring-type'], hue=Mushroom_data["class"]);

# %%
plt.figure(figsize=[10,6])
plt.title('Comparison between ring-type and spore-print-color')
sns.scatterplot(Mushroom_data['ring-type'], Mushroom_data['spore-print-color'], hue=Mushroom_data["class"]);

# %% [markdown]
# plt.figure(figsize=[10,6])
# plt.title('Comparison between spore-print-color and population')
# sns.scatterplot(Mushroom_data['spore-print-color'], Mushroom_data['population'], hue=Mushroom_data["class"]);

# %%
plt.figure(figsize=[10,6])
plt.title('Comparison between population and habitat')
sns.scatterplot(Mushroom_data['population'], Mushroom_data['habitat'], hue=Mushroom_data["class"]);

# %% [markdown]
# From the above scatterplots we cannot find any correlation between columns.

# %%
sns.pairplot(Mushroom_data,hue="class")   #multivariate analysis

# %%
cor=Mushroom_data.corr()

# %%
cor
# Out:
#                           cap-shape  cap-surface  cap-color   bruises  \
# cap-shape                  1.000000    -0.050454  -0.048203 -0.035374
# cap-surface               -0.050454     1.000000  -0.019402  0.070228
# cap-color                 -0.048203    -0.019402   1.000000 -0.000764
# bruises                   -0.035374     0.070228  -0.000764  1.000000
# odor                      -0.021935     0.045233  -0.387121 -0.061825
# gill-attachment            0.078865    -0.034180   0.041436  0.137359
# gill-spacing               0.013196    -0.282306   0.144259 -0.299473
# gill-size                  0.054050     0.208100  -0.169464 -0.369596
# gill-color                -0.006039    -0.161017   0.084659  0.527120
# stalk-shape                0.063794    -0.014123  -0.456496  0.099364
# stalk-root                 0.030191    -0.126245   0.321274  0.244188
# stalk-surface-above-ring  -0.030417     0.089090  -0.060837  0.460824
# ...

# %%
Mushroom_data.describe()
# Out:
#          cap-shape  cap-surface    cap-color      bruises         odor  \
# count  8124.000000  8124.000000  8124.000000  8124.000000  8124.000000
# mean      3.348104     1.827671     4.504677     0.415559     4.144756
# std       1.604329     1.229873     2.545821     0.492848     2.103729
# min       0.000000     0.000000     0.000000     0.000000     0.000000
# 25%       2.000000     0.000000     3.000000     0.000000     2.000000
# 50%       3.000000     2.000000     4.000000     0.000000     5.000000
# 75%       5.000000     3.000000     8.000000     1.000000     5.000000
# max       5.000000     3.000000     9.000000     1.000000     8.000000
#
#        gill-attachment  gill-spacing    gill-size   gill-color  stalk-shape  \
# count      8124.000000   8124.000000  8124.000000  8124.000000  8124.000000
# mean          0.974151      0.161497     0.309207     4.810684     0.567208
# std           0.158695      0.368011     0.462195     3.540359     0.495493
# ...

# %% [markdown]
# From the above statistics table we can see that minimum value for each column is 0
#
# and values for various percentiles increases as the percentile increases.

# %%
import matplotlib.pyplot as plt

fig, ax = plt.subplots(figsize=(15,15))         # Sample figsize in inches
sns.heatmap(cor, annot=True, linewidths=.5, ax=ax)
# Out:
# <AxesSubplot:>

# %% [markdown]
# From the above correlation values of the heatmap we can see that correlation between column data is not present

# %% [markdown]
# # SCALING

# %% [markdown]
# Scaling is not required here because all the data in columns not having huge difference between them.

# %%
x=Mushroom_data.drop("class",axis=1)   #indeppendent varaibles 
y=Mushroom_data["class"]           #dependent varaiable

# %%
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score

for i in range(200):
    x_train, x_test, y_train, y_test=train_test_split(x,y,test_size=0.33, random_state=i)
    from sklearn.tree import DecisionTreeClassifier
    lm=DecisionTreeClassifier()
    lm.fit(x_train,y_train)
    pred=lm.predict(x_test)
    accu=accuracy_score(y_test,pred)
    print(accu*100, "at random_state", i)
# Out:
# 100.0 at random_state 0
# 100.0 at random_state 1
# 100.0 at random_state 2
# 100.0 at random_state 3
# 100.0 at random_state 4
# 100.0 at random_state 5
# 100.0 at random_state 6
# 100.0 at random_state 7
# 100.0 at random_state 8
# 100.0 at random_state 9
# 100.0 at random_state 10
# 100.0 at random_state 11
# 100.0 at random_state 12
# 100.0 at random_state 13
# 100.0 at random_state 14
# 100.0 at random_state 15
# 100.0 at random_state 16
# 100.0 at random_state 17
# 100.0 at random_state 18
# 100.0 at random_state 19
# 100.0 at random_state 20
# 100.0 at random_state 21
# 100.0 at random_state 22
# 100.0 at random_state 23
# 100.0 at random_state 24
# 100.0 at random_state 25
# 100.0 at random_state 26
# 100.0 at random_state 27
# 100.0 at random_state 28
# 100.0 at random_state 29
# 100.0 at random_state 30
# 100.0 at random_state 31
# 100.0 at random_state 32
# 100.0 at random_state 33
# 100.0 at random_state 34
# 100.0 at random_state 35
# 100.0 at random_state 36
# ...

# %%
from sklearn.tree import DecisionTreeClassifier
maxAccu=0
maxRS=0
for i in range(1,200):
    x_train, x_test, y_train, y_test=train_test_split(x,y,test_size=0.30, random_state=i)
    mod=DecisionTreeClassifier()
    mod.fit(x_train,y_train)
    pred=mod.predict(x_test)
    acc=accuracy_score(y_test,pred)
    if acc>maxAccu:
        maxAccu=acc
        maxRS=i
print("Best accuracy is ", maxAccu, "on Random_state", maxRS)
# Out:
# Best accuracy is  1.0 on Random_state 1

# %% [markdown]
# Best accuracy is 1 at random state 1

# %%
x_train, x_test, y_train, y_test=train_test_split(x,y,test_size=0.30, random_state=1)

# %% [markdown]
# Now we are checking accuracy using various algorithm.

# %%
from sklearn.svm import SVC
from sklearn.metrics import classification_report
from sklearn.ensemble import RandomForestClassifier
from sklearn.ensemble import AdaBoostClassifier
from sklearn.metrics import confusion_matrix
from sklearn.ensemble import GradientBoostingClassifier

# %%
rf=RandomForestClassifier(n_estimators=100,random_state=1)
#RandomForestClassifier(100)----> Default
rf.fit(x_train,y_train)
predrf=rf.predict(x_test)
print(accuracy_score(y_test,predrf))
print(confusion_matrix(y_test,predrf))
print(classification_report(y_test,predrf))
# Out:
# 1.0
# [[1236    0]
#  [   0 1202]]
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00      1236
#            1       1.00      1.00      1.00      1202
#
#     accuracy                           1.00      2438
#    macro avg       1.00      1.00      1.00      2438
# weighted avg       1.00      1.00      1.00      2438

# %%
#AdaBoostClassifier(base_estimator=DecisionTreeClassifier(),n_estimators=50,learning_rate=1.0)
ad=AdaBoostClassifier()
ad.fit(x_train,y_train)
ad_pred=ad.predict(x_test)
print(accuracy_score(y_test,ad_pred))
print(confusion_matrix(y_test,ad_pred))
print(classification_report(y_test,ad_pred))
# Out:
# 1.0
# [[1236    0]
#  [   0 1202]]
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00      1236
#            1       1.00      1.00      1.00      1202
#
#     accuracy                           1.00      2438
#    macro avg       1.00      1.00      1.00      2438
# weighted avg       1.00      1.00      1.00      2438

# %%
# Import Support vector classifier
from sklearn.svm import SVC
SV = SVC()
SV.fit(x_train, y_train)
pred = SV.predict(x_test)
acc=classification_report(y_test, pred)
print(acc)
# Out:
#               precision    recall  f1-score   support
#
#            0       0.97      1.00      0.99      1236
#            1       1.00      0.97      0.99      1202
#
#     accuracy                           0.99      2438
#    macro avg       0.99      0.99      0.99      2438
# weighted avg       0.99      0.99      0.99      2438

# %%
from sklearn.ensemble import GradientBoostingClassifier
gb=GradientBoostingClassifier()
gb.fit(x_train,y_train)
gb_pred=gb.predict(x_test)
print(accuracy_score(y_test,gb_pred))
print(confusion_matrix(y_test,gb_pred))
print(classification_report(y_test,gb_pred))
# Out:
# 1.0
# [[1236    0]
#  [   0 1202]]
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00      1236
#            1       1.00      1.00      1.00      1202
#
#     accuracy                           1.00      2438
#    macro avg       1.00      1.00      1.00      2438
# weighted avg       1.00      1.00      1.00      2438

# %% [markdown]
# Now we will check the cross validation score

# %%
from sklearn.model_selection import cross_val_score

# %%
print(cross_val_score(rf,x,y,cv=5).mean())
# Out:
# 0.8962016672982192

# %%
print(cross_val_score(ad,x,y,cv=5).mean())
# Out:
# 0.5179714285714285

# %%
print(cross_val_score(SV,x,y,cv=5).mean())
# Out:
# 0.841292231906025

# %%
print(cross_val_score(gb,x,y,cv=5).mean())
# Out:
# 0.91738446381205

# %% [markdown]
# THE value with least difference will be the best model. here gb(Gradient Booster Classifier) has been
#
# chosen as the best model for hyper parameter tuning

# %% [markdown]
# # Hyper parameter tuning

# %%
from sklearn.model_selection import GridSearchCV

# %%
parameter = {'loss':['deviance','exponential'],
            'n_estimators':np.arange(2,10), 
            'criterion':['friedman_mse','squared_error','mse','mae'],
            'max_depth' :np.arange(1,8)}

# %%
GCV=GridSearchCV(GradientBoostingClassifier(),parameter,cv=5)

# %%
GCV.fit(x_train,y_train)
# Out:
# GridSearchCV(cv=5, estimator=GradientBoostingClassifier(),
#              param_grid={'criterion': ['friedman_mse', 'squared_error', 'mse',
#                                        'mae'],
#                          'loss': ['deviance', 'exponential'],
#                          'max_depth': array([1, 2, 3, 4, 5, 6, 7]),
#                          'n_estimators': array([2, 3, 4, 5, 6, 7, 8, 9])})

# %%
GCV.best_params_
# Out:
# {'criterion': 'friedman_mse',
#  'loss': 'deviance',
#  'max_depth': 7,
#  'n_estimators': 2}

# %%
Final_model = GradientBoostingClassifier(criterion = 'friedman_mse', loss = 'deviance', max_depth = 7, n_estimators = 2)
Final_model.fit(x_train, y_train)
pred = Final_model.predict(x_test)
acc=accuracy_score(y_test, pred)
print(acc*100)
# Out:
# 100.0

# %%
import numpy as np 
from sklearn .metrics import roc_auc_score 
auc = np.round(roc_auc_score(y_test,pred), 3) 
print("AUC for our sample data is",(auc))
# Out:
# AUC for our sample data is 1.0

# %%
import numpy as np
from sklearn import metrics
import matplotlib.pyplot as plt
AUC_ROC = metrics.roc_curve(y_test,pred)
plt.plot(AUC_ROC)
plt.ylabel('True Positive Rate')
plt.xlabel('False Positive Rate')
plt.show()

# %% [markdown]
# Value of AUC-ROC shows that model is successful at separating different classes

# %% [markdown]
# # SAVING THE MODEL

# %%
import joblib
joblib.dump(Final_model,"FinalModel.pkl")
# Out:
# ['FinalModel.pkl']
